# %%
import tkinter as tk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plot
import seaborn as sns
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from tkinter import *
import time
import datetime


root = Tk()

data = pd.read_csv("C:\\users\\districtcrime1.csv")

# %%
def years():
    root = tk.Tk()
    df = pd.DataFrame(data)
    no_total = df.loc[df.DISTRICT != 'Total', :]
    yr_totals = no_total.groupby('YEAR')
    yr_agg = yr_totals.sum().reset_index()
    cols = list(yr_agg.columns)
    cols.remove('YEAR')
    cols.remove('TOTAL IPC CRIMES')
    cols.remove('OTHER IPC CRIMES')
    fig1 = plot.figure()
    fig1.set_size_inches(15, 10)
    ax = plot.subplot(111)
    ax.set_xlim([2001, 2015])
    ax.set_title("Crime committed in India (in ten thousands)")
    ax.set_xlabel("Year")
    ax.set_ylabel("Number of cases filed")
    for col in cols:
        ax.plot(yr_agg.YEAR, yr_agg[col], label=col.replace('_', ' '))
        ax.legend(loc=5, bbox_to_anchor=(1.5, .5))
        bar1 = FigureCanvasTkAgg(fig1, root)
        bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
        figure1 = plt.Figure(figsize=(16,16), dpi=100)
root.mainloop()

def world():
    # Pie chart
    root = tk.Tk();
    labels = ['MURDER', 'ATTEMPT TO MURDER','CULPABLE HOMICIDE NOT AMOUNTING TO MURDER','KIDNAPPING AND ABDUCTION OF OTHERS']
    sizes = [939261, 858171,102599,77410]
    # only "explode" the 2nd slice (i.e. 'Hogs')
    explode = (0, 0.1, 0, 0)

    #add colors
    colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',    shadow=True, startangle=90)
    

    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
    #ax1.set_title('Male Vs Female ratio')
     # Pie chart
    labels = ['AUTO THEFT','OTHER THEFT','RIOTS','CHEATING','HURT/GREVIOUS HURT']
    sizes = [2862820,4869180,1756143,1756442,7415665]

    # only "explode" the 2nd slice 
    explode = (0, 0.1, 0, 0,0)

    #add colors
    colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
    shadow=True, startangle=90)

    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')

    plt.tight_layout()

    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,12), dpi=100)
    plt.show()
    
    # Pie chart
    labels = ['CRUELTY BY HUSBAND ON WIFE','IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES','CAUSING DEATH BY NEGLIGENCE','OTHER IPC CRIMES','TOTAL IPC CRIMES']  
    sizes = [274627,2046576,886774,2597435,22287246]

    # only "explode" the 2nd slice 
    explode = (0, 0.8, 0, 0,0)

    #add colors
    colors = ['#ff9999','#66b3ff','#99ff99','red','blue']

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%2.1f%%',
    shadow=True, startangle=90)

    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')

    plt.tight_layout()
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,12), dpi=100)
    plt.show()
    

    root.mainloop()



data_total = data[data['DISTRICT'] == 'TOTAL']
# drop DISTRCT Column as we do not intend to use at this point
data_total.drop('DISTRICT', axis=1, inplace=True)
# filter out the Total crimes for each State & UT 
data_total_2001 = data_total[data_total['YEAR'] == 2001]
data_total_2001.drop('YEAR', axis=1, inplace=True)

def world():
    # Pie chart
    root = tk.Tk();
    labels = ['MURDER', 'ATTEMPT TO MURDER','CULPABLE HOMICIDE NOT AMOUNTING TO MURDER','KIDNAPPING AND ABDUCTION OF OTHERS']
    sizes = [939261, 858171,102599,77410]
    # only "explode" the 2nd slice (i.e. 'Hogs')
    explode = (0, 0.1, 0, 0)

    #add colors
    colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',    shadow=True, startangle=90)
    

    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
    #ax1.set_title('Male Vs Female ratio')
     # Pie chart
    labels = ['AUTO THEFT','OTHER THEFT','RIOTS','CHEATING','HURT/GREVIOUS HURT']
    sizes = [2862820,4869180,1756143,1756442,7415665]

    # only "explode" the 2nd slice 
    explode = (0, 0.1, 0, 0,0)

    #add colors
    colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
    shadow=True, startangle=90)

    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')

    plt.tight_layout()

    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,12), dpi=100)
    plt.show()
    
    # Pie chart
    labels = ['CRUELTY BY HUSBAND ON WIFE','IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES','CAUSING DEATH BY NEGLIGENCE','OTHER IPC CRIMES','TOTAL IPC CRIMES']  
    sizes = [274627,2046576,886774,2597435,22287246]

    # only "explode" the 2nd slice 
    explode = (0, 0.8, 0, 0,0)

    #add colors
    colors = ['#ff9999','#66b3ff','#99ff99','red','blue']

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%2.1f%%',
    shadow=True, startangle=90)

    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')

    plt.tight_layout()
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,12), dpi=100)
    plt.show()
    

    root.mainloop()
    
def mworld():
    root = tk.Tk()
    fig1, ax = plt.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['MURDER'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom   
    fig1.set_size_inches(20, 18, forward=True)
    ax.set_xlabel('MURDER')
    ax.set_title('MURDER VS STATE/UT')
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,12), dpi=100)
    plt.show()
root.mainloop()

def am():
    root=tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['ATTEMPT TO MURDER'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER= data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['ATTEMPT TO MURDER'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('ATTEMPT TO MURDER')
    ax.set_title('ATTEMPT TO MURDER VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,12), dpi=100)
root.mainloop()

def fworld():
    root = tk.Tk()
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['CULPABLE HOMICIDE NOT AMOUNTING TO MURDER'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER= data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['MURDER'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('CULPABLE HOMICIDE NOT AMOUNTING TO MURDER')
    ax.set_title('CULPABLE HOMICIDE NOT AMOUNTING TO MURDER VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
    
plt.show()
root.mainloop()

def cr():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['CUSTODIAL RAPE'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER= data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['MURDER'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('CUSTODIAL RAPE')
    ax.set_title('CUSTODIAL RAPE VS STATE/UT') 
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
root.mainloop()

def Otherrape():
    root = tk.Tk()
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['OTHER RAPE'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER ))
    performance = data_total_2001['OTHER RAPE'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('OTHER RAPE')
    ax.set_title('OTHER RAPE VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
root.mainloop()

def medalindia():
    root = tk.Tk()
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['KIDNAPPING AND ABDUCTION OF OTHERS'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER ))
    performance = data_total_2001['KIDNAPPING AND ABDUCTION OF OTHERS'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('KIDNAPPING AND ABDUCTION OF OTHERS')
    ax.set_title('KIDNAPPING AND ABDUCTION OF OTHERS VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
    
root.mainloop()

def at():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['AUTO THEFT'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['AUTO THEFT'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('AUTO THEFT')
    ax.set_title('AUTO THEFT VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,16), dpi=100)
    
root.mainloop()


def sportmedals():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['OTHER THEFT'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER ))
    performance = data_total_2001['OTHER THEFT'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER )
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('OTHER THEFT')
    ax.set_title('OTHER THEFT VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop()

def fmedal():
    root = tk.Tk()
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['RIOTS'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER= data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['RIOTS'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('RIOTS')
    ax.set_title('RIOTS VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop()

def c():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['CHEATING'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['CHEATING'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('CHEATING')
    ax.set_title('CHEATING VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop()

def hurt():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['HURT/GREVIOUS HURT'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['HURT/GREVIOUS HURT'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('HURT/GREVIOUS HURT')
    ax.set_title('HURT/GREVIOUS HURT VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop()

def mmedal():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['DOWRY DEATHS'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['DOWRY DEATHS'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('DOWRY DEATHS')
    ax.set_title('DOWRY DEATHS VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop()

def ygold():    
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['CRUELTY BY HUSBAND OR HIS RELATIVES'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['CRUELTY BY HUSBAND OR HIS RELATIVES'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('CRUELTY BY HUSBAND OR HIS RELATIVES')
    ax.set_title('CRUELTY BY HUSBAND OR HIS RELATIVES VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop

def girls():
    root = tk.Tk()
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES')
    ax.set_title('IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
    root.mainloop
plot.show()

def cd():
    root = tk.Tk()
    #13......CAUSING DEATH BY NEGLIGENCE VS STATE
    # filter out the Total crimes for each State & UT 
    data_total_2001 = data_total[data_total['YEAR'] == 2001]
    data_total_2001.drop('YEAR', axis=1, inplace=True)
    # Data of Rape crime committed in the year 2001 per state
    x = data_total_2001['STATE/UT'].values
    y = data_total_2001['CAUSING DEATH BY NEGLIGENCE'].values
    # plot the bar graph
    fig1, ax = plot.subplots()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(data_MURDER))
    performance = data_total_2001['CAUSING DEATH BY NEGLIGENCE'].values
    ax.barh(y_pos, performance, align='center',color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(data_MURDER)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('CAUSING DEATH BY NEGLIGENCE')
    ax.set_title('CAUSING DEATH BY NEGLIGENCE VS STATE/UT')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop
# Out:
# C:\Users\DEll\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# <bound method Misc.mainloop of <tkinter.Tk object .>>

# %%
def cs():
    root = tk.Tk()
    import pandas as pd 
    data = pd.read_csv("C:\\users\\districtcrime1.csv") 
    data

    data.rename(columns={'STATE/UT':'STATE'}, inplace=True)

    # calculating total crimes of all kinds in each state from 2001 to 2014
    data= data[data['DISTRICT'] == 'TOTAL']
    data.drop('DISTRICT', axis=1, inplace=True)


    data['Total Crimes']= data.iloc[:, -9:-1].sum(axis=1)

    data = data.groupby(['STATE'])['Total Crimes'].sum()
    print (data)

    # plot graph of crimes committed  since 2001-2014 in each state/ UT
    fig1, ax1 = plot.subplots()
    states = data.tolist()
    data_MURDER = data_total_2001['STATE/UT'].values
    y_pos = np.arange(len(states))
    performance = data.tolist()
    ax1.barh(y_pos, performance, align='center',color='blue', ecolor='green')
    ax1.set_yticks(y_pos)
    ax1.set_yticklabels(states)
    ax1.invert_yaxis()  
    # labels read top-to-bottom
    ax1.set_xlabel('All Crimes ')
    ax1.set_title('Crime VS STATE')
    fig1.set_size_inches(20, 18, forward=True)
    bar1 = FigureCanvasTkAgg(fig1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    figure1 = plt.Figure(figsize=(16,8), dpi=100)
root.mainloop
# Out:
# <bound method Misc.mainloop of <tkinter.Tk object .>>

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
data = pd.read_csv("C:\\users\\DELL\\Desktop\\crime.csv") 
data.head()
data['status'] = ((data['MURDER']*8+
                           data['ATTEMPT TO MURDER']*8+
                           data['CULPABLE HOMICIDE NOT AMOUNTING TO MURDER']*7+
                           data['CUSTODIAL RAPE']*10+
                           data['OTHER RAPE']*10+
                           data['KIDNAPPING AND ABDUCTION OF OTHERS']*8+
                           data['AUTO THEFT']*7+data['OTHER THEFT']*6+
                           data['RIOTS']*7+data['CHEATING']*7+
                           data['HURT/GREVIOUS HURT']*7+
                           data['DOWRY DEATHS']*10+
                           data['CRUELTY BY HUSBAND OR HIS RELATIVES']*9+
                           data['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES']*8+
                           data['CAUSING DEATH BY NEGLIGENCE']*8+data['OTHER IPC CRIMES']*8+
                           data['TOTAL IPC CRIMES']*7))



def status2(x):
    if x>100000 :
        return ("crime prone")
    else :
        return ( "crime less")
data['crime_status'] = data['status'].apply(status2)

dataframe=pd.DataFrame(data)
array = dataframe.values

X1 = array[:,3:7]

Y1 = array[:,21]

clf = RandomForestClassifier()
fclf = clf.fit(X1,Y1)



P1=[[101, 50, 16 ,175]]
result=str(fclf.predict(P1))
#messagebox.showinfo (title= 'Result' , message="Hello" '%s \n As per the calculation, \n You are %s' %(name,result))
print(result)

P2=[[111, 37, 24 ,746]]
result=str(fclf.predict(P2))
#messagebox.showinfo (title= 'Result' , message="Hello" '%s \n As per the calculation, \n You are %s' %(name,result))
print(result)
# Out:
# C:\Users\DEll\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ['crime less']
# ['crime less']

# %%
m = input ("no. of murders ")
r = input ("no. of rapes ")
d = input ("no. of dowry deaths ")
c = input ("no. of cases CRUELTY BY HUSBAND OR HIS RELATIVES  ")

P2=[[m, r, d , c]]
result=str(fclf.predict(P2))
#messagebox.showinfo (title= 'Result' , message="Hello" '%s \n As per the calculation, \n You are %s' %(name,result))
print(result)
# Out:
# no. of murders 45
# no. of rapes 21124
# no. of dowry deaths 21
# no. of cases CRUELTY BY HUSBAND OR HIS RELATIVES  545
# ['crime less']

# %%
from tkinter import *
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB 

from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB 

import pandas
import numpy as np
import math
from tkinter import messagebox as m_box

# %%
data = pd.read_csv("C:\\users\\DELL\\Desktop\\crime.csv") 
data.head()
data['status'] = ((data['MURDER']*8+
                           data['ATTEMPT TO MURDER']*8+
                           data['CULPABLE HOMICIDE NOT AMOUNTING TO MURDER']*7+
                           data['CUSTODIAL RAPE']*10+
                           data['OTHER RAPE']*10+
                           data['KIDNAPPING AND ABDUCTION OF OTHERS']*8+
                           data['AUTO THEFT']*7+data['OTHER THEFT']*6+
                           data['RIOTS']*7+data['CHEATING']*7+
                           data['HURT/GREVIOUS HURT']*7+
                           data['DOWRY DEATHS']*10+
                           data['CRUELTY BY HUSBAND OR HIS RELATIVES']*9+
                           data['IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES']*8+
                           data['CAUSING DEATH BY NEGLIGENCE']*8+data['OTHER IPC CRIMES']*8+
                           data['TOTAL IPC CRIMES']*7))
#data

def status2(x):
    if x>100000:
        return ("crime prone")
    else :
        return ( "crime less")
data['crime_status'] = data['status'].apply(status2)

dataframe=pd.DataFrame(data)
array = dataframe.values

X1 = array[:,3:11]

Y1 = array[:,21]

clf = RandomForestClassifier()
fclf = clf.fit(X1,Y1)
P1=[[101, 50, 16 ,175,54,45,21,658]]
result=str(fclf.predict(P1))
#messagebox.showinfo (title= 'Result' , message="Hello" '%s \n As per the calculation, \n You are %s' %(name,result))
print(result)

P2=[[111, 37, 24 ,746,453,453,214,875]]
result=str(fclf.predict(P2))
#messagebox.showinfo (title= 'Result' , message="Hello" '%s \n As per the calculation, \n You are %s' %(name,result))
print(result)
m = input ("no. of murders ")
r = input ("no. of rapes ")
d = input ("no. of dowry deaths ")
c = input ("no. of cases CRUELTY BY HUSBAND OR HIS RELATIVES  ")
cu = input ("no. of CULPABLE HOMICIDE NOT AMOUNTING TO MURDER ")
k = input ("no. of KIDNAPPING AND ABDUCTION OF OTHERS ")
a = input ("Auto theft")
ri = input ("RIOTS")
 
P2=[[m, r, d , c,cu,k,a,ri]]
result=str(fclf.predict(P2))
print(result)
# Out:
# C:\Users\DEll\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ['crime less']
# ['crime prone']
# no. of murders 512
# no. of rapes 234
# no. of dowry deaths 214
# no. of cases CRUELTY BY HUSBAND OR HIS RELATIVES  1215
# no. of CULPABLE HOMICIDE NOT AMOUNTING TO MURDER 212
# no. of KIDNAPPING AND ABDUCTION OF OTHERS 452
# Auto theft212
# RIOTS214
# ['crime prone']

# %%
def show_entry_fields():
        print("MURDER: %s\nRAPES %s\nDOWRY DEATHS %s\nCRUELTY BY HUSBAND OR HIS RELATIVES %s\nCULPABLE HOMICIDE NOT AMOUNTING TO MURDER %s\nKIDNAPPING AND ABDUCTION OF OTHERS %s\nAUTO THEFT %s\nOTHER THEFT %s\nRIOTS %s\nCHEATING %s\nIMPORTATION OF GIRLS FROM FOREIGN COUNTRIES %s\nCAUSING DEATH BY NEGLIGENCE%s\nAuto theft%s\nRIOTS: %s" % (e1.get(), e2.get() , e3.get(), e4.get()  , e5.get() , e6.get() , e7.get(), e8.get() ,e9.get(), e10.get(),e11.get()))

# %%
master= tk.Tk()
master.title('PREDICT CITIES')
def submit():

    
    
    Label(master, text="MURDER").grid(row=0 , column = 10)
    Label(master, text="RAPES").grid(row=1 , column = 10)
    Label(master, text="DOWRY DEATHS").grid(row=2, column = 10)
    Label(master, text="CRUELTY BY HUSBAND OR HIS RELATIVES").grid(row=3, column = 10)
    Label(master, text="CULPABLE HOMICIDE NOT AMOUNTING TO MURDER").grid(row=4 , column = 10)
    Label(master, text="KIDNAPPING AND ABDUCTION OF OTHERS").grid(row=5 , column = 10)
    Label(master, text="AUTO THEFT").grid(row=6 , column = 10)
    Label(master, text="RIOTS").grid(row=7 , column = 10)
    





    e1 = Entry(master)
    e2 = Entry(master)  
    e3 = Entry(master)
    e4 = Entry(master)
    e5 = Entry(master)
    e6 = Entry(master)
    e7 = Entry(master)
    e8 = Entry(master)
    



    e1.grid(row=0, column=11)
    e2.grid(row=1, column=11)
    e3.grid(row=2, column=11)
    e4.grid(row=3, column=11)
    e5.grid(row=4, column=11) 
    e6.grid(row=5, column=11)
    e7.grid(row=6, column=11)
    e8.grid(row=7, column=11)





    # m_box.showwarning('title', 'content of this message box !! ')
    m=e1.get()
    m=e2.get()
    m=e3.get()
    m=e4.get()
    m=e5.get()
    m=e6.get()    
    m=e7.get() 
    m=e8.get() 
    
    P2=[[m, r, d , c,cu, k,a,ri]]
    result=str(fclf.predict(P2))
    #result = 'crime'
    m_box.showerror('PREDICTION', result)





    Button(master, text='QUIT', command=master.quit).grid(row=12, column=0, sticky=W, pady=4)
    Button(master, text='PREDICT', command=submit).grid(row=12, column=11, sticky=W, pady=4)






#submit_btn = ttk.Button(master, text = 'Submit', command=submit)



master.mainloop()

# %%
from tkinter import *
import tkinter as tk
import tkinter as ttk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB 
from tkinter import *
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB 

import pandas as  pd
import numpy as np
import math
from tkinter import messagebox as m_box


import pandas as  pd
import numpy as np
import math


data = pd.read_csv("C:\\users\\districtcrime1.csv") 





#from PIL import Image,IMAGETK

crime_root = Tk()

#width X Height
crime_root.geometry("1280x720")

#frame
f1 = Frame(crime_root, bg="gray", borderwidth=4, relief=SUNKEN)
f1.pack (side= "left", fill="y")





#button
##b1.pack()
#lable


#menu button crime
mb = Menubutton (f1,text="CRIME VISUALIZATION")
mb.menu = Menu(mb)
mb["menu"] = mb.menu

mb.menu.add_command(label="RATIO OF CRIME", command=world)   
mb.menu.add_command(label="MURDER", command=mworld)  #: print ("MURDER"))
mb.menu.add_command(label="ATTEMPT TO MURDER", command=am) #: print ("ATTEMPT TO MURDER"))
mb.menu.add_command(label="CULPABLE HOMICIDE NOT AMOUNTING TO MURDER", command=fworld) #: print ("CULPABLE HOMICIDE NOT AMOUNTING TO MURDER"))
mb.menu.add_command(label="CUSTODIAL RAPE", command=cr)  #: print ("CUSTODIAL RAPE"))
mb.menu.add_command(label="OTHER RAPE", command=Otherrape)  #: print ("OTHER RAPE"))
mb.menu.add_command(label="KIDNAPPING AND ABDUCTION OF OTHERS", command=medalindia) #: print ("KIDNAPPING AND ABDUCTION OF OTHERS"))
mb.menu.add_command(label="AUTO THEFT", command=at )  #: print ("AUTO THEFT"))
mb.menu.add_command(label="OTHER THEFT", command=sportmedals ) #: print ("OTHER THEFT"))
mb.menu.add_command(label="RIOTS", command=fmedal)   #: print ("RIOTS"))
mb.menu.add_command(label="CHEATING", command=c ) #: print ("CHEATING"))
mb.menu.add_command(label="HURT/GREVIOUS HURT", command=hurt )  #: print ("HURT/GREVIOUS HURT"))
mb.menu.add_command(label="DOWRY DEATHS", command=mmedal )#: print ("DOWRY DEATHS"))
mb.menu.add_command(label="CRUELTY BY HUSBAND OR HIS RELATIVES", command=ygold)  #: print ("CRUELTY BY HUSBAND OR HIS RELATIVES"))
mb.menu.add_command(label="IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES", command=girls)  #: print ("IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES"))
mb.menu.add_command(label="CAUSING DEATH BY NEGLIGENCE", command=cd  )#: print ("CAUSING DEATH BY NEGLIGENCE"))



mb.pack(padx = 10)


#button1= Button(text="click here",command=years,bd = 5, fg = "black",font=('mistral',15,),width=12,bg="grey")
#button1.grid(row=0,column=20)

#label
l = Label(f1, text="Select crime for visulaization ↑")
l.pack ( pady=142)
#imaage
photo = PhotoImage (file="1 (2).png")


#f2 = Frame(crime_root, bg="gray", borderwidth=4, relief=SUNKEN)
#f2.pack (side= "left", fill="y")


mb = Menubutton (f1,text="CLICK FOR TOTAL")
mb.menu = Menu(mb)
mb["menu"] = mb.menu


mb.menu.add_command(label="FOR TOTAL", command=cs) 
mb.menu.add_command(label="CRIME COMMITED VS YEARS", command=years)


mb.pack(padx = 10)











f2 = Frame(crime_root, bg="gray", borderwidth=4, relief=SUNKEN)
f2.pack (side= "right", fill="y")




mb = Menubutton (f2 , text="STATE")
mb.menu = Menu(mb)
mb["menu"] = mb.menu


mb.menu.add_command(label="Andhra Pradesh",command=lambda:print("Andhra Pradesh")) 
mb.menu.add_command(label="Arunachal Pradesh	" ,command=lambda:print("Arunachal Pradesh")) 
mb.menu.add_command(label="Assam" ,command=lambda:print("Assam")) 
mb.menu.add_command(label="Bihar",command=lambda:print("Bihar")) 
mb.menu.add_command(label="Chhattisgarh" ,command=lambda:print("Chhattisgarh")) 
mb.menu.add_command(label="Goa" ,command=lambda:print("Goa")) 
mb.menu.add_command(label="Gujarat",command=lambda:print("Gujarat")) 
mb.menu.add_command(label="Haryana",command=lambda:print("Haryana"))  
mb.menu.add_command(label="Himachal Pradesh",command=lambda:print("Himachal Pradesh")) 
mb.menu.add_command(label="Jammu and Kashmir" ,command=lambda:print("Jammu and Kashmir")) 
mb.menu.add_command(label="Jharkhand" ,command=lambda:print("Jharkhand")) 
mb.menu.add_command(label="Karnataka" ,command=lambda:print("Karnataka")) 
mb.menu.add_command(label="	Kerala"  ,command=lambda:print("	Kerala" )) 
mb.menu.add_command(label="Madhya Pradesh" ,command=lambda:print("Madhya Pradesh"  ))
mb.menu.add_command(label="Maharashtra",command=lambda:print("Maharashtra" ))
mb.menu.add_command(label="Manipur" ,command=lambda:print("Manipur" )) 
mb.menu.add_command(label="Meghalaya" ,command=lambda:print("Meghalaya"))
mb.menu.add_command(label="Mizoram",command=lambda:print("Mizoram"))
mb.menu.add_command(label="	Nagaland" ,command=lambda:print("	Nagaland"))
mb.menu.add_command(label="Odisha",command=lambda:print("Odisha")) 
mb.menu.add_command(label="Punjab",command=lambda:print("Punjab")) 
mb.menu.add_command(label="Rajasthan" ,command=lambda:print("Rajasthan")) 
mb.menu.add_command(label="Sikkim" ,command=lambda:print("Sikkim")) 
mb.menu.add_command(label="Tamil Nadu" ,command=lambda:print("Tamil Nadu"))  
mb.menu.add_command(label="Telangana",command=lambda:print("Telangana"))   
mb.menu.add_command(label="Tripura",command=lambda:print("Tripura"))
mb.menu.add_command(label="Uttar Pradesh" ,command=lambda:print("Uttar Pradesh"))
mb.menu.add_command(label="Uttarakhand" ,command=lambda:print("Uttarakhand" ))
mb.menu.add_command(label="West Bengal",command=lambda:print("West Bengal"))



mb.pack(padx=10)












l = Label(f2, text="SELECT STATE\n FROM ABOVE \n AND THEN \n INPUT DATA \n FOR  FIND \n OUT WHICH\n STATE IS \n\n  CRIME FREE \n\n OR \n\n CRIME LESS")
l.pack ( pady=100)








#menu button crime
mb = Menubutton (f2,text="CLICK FOR PREDICTION")
mb.menu = Menu(mb)
mb["menu"] = mb.menu

mb.menu.add_command(label="PREDICT", command=submit)   




mb.pack(padx = 10)







f3 = Frame(crime_root, bg="blue", borderwidth=70, relief=SUNKEN)
f3.pack (side= "top", fill="both")





mb = Menubutton (f3 , text="CRIME ANALYSIS AND PREDICTION")




mb.pack(padx=50)

#f4 = Frame(crime_root, bg="blue", borderwidth=70, relief=SUNKEN)
#f4.pack (side= "right", fill="y")





#window Title
Crime_label = Label(image =photo)
Crime_label.pack()





#Label(crime_root,  text="MURDER").place(x=50, y = 60)
#Label(crime_root, text="RAPES").grid(row=1 , column = 10)
#Label(crime_root, text="DOWRY DEATHS").grid(row=2, column = 10)
#Label(crime_root, text="CRUELTY BY HUSBAND OR HIS RELATIVES").grid(row=3, column = 10)
#jpg Import
crime_root.title("CAP")

#label
#aksh = Label(text="my name is aksh")
#aksh.pack()
crime_root.mainloop()



root.mainloop()
# Out:
# C:\Users\DEll\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# Himachal Pradesh
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\DEll\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-0af702c0604e>", line 7, in submit
#     Label(master, text="MURDER").grid(row=0 , column = 10)
#   File "C:\Users\DEll\Anaconda3\lib\tkinter\__init__.py", line 2766, in __init__
#     Widget.__init__(self, master, 'label', cnf, kw)
#   File "C:\Users\DEll\Anaconda3\lib\tkinter\__init__.py", line 2299, in __init__
#     (widgetName, self._w) + extra + self._options(cnf))
# _tkinter.TclError: can't invoke "label" command: application has been destroyed

# %%
pwd
# Out:
# 'C:\\Users\\DEll\\Desktop\\CRIME ANALYSIS'
